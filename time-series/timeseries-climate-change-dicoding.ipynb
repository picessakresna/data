# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
import kaggle

# Set the Kaggle API credentials
kaggle.api.authenticate()

# Download the dataset
kaggle.api.dataset_download_files('berkeleyearth/climate-change-earth-surface-temperature-data', path='./dataset', unzip=True)

# %%
files = os.listdir('./dataset')

for file in files:
    if file != 'GlobalLandTemperaturesByMajorCity.csv':
        os.remove(os.path.join('./dataset', file))

# %%
df = pd.read_csv('./dataset/GlobalLandTemperaturesByMajorCity.csv')
df.head
# Out:
# <bound method NDFrame.head of                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
# 239176  2013-09-01                 NaN                            NaN
#
#            City        Country Latitude Longitude
# 0       Abidjan  Côte D'Ivoire    5.63N     3.23W
# 1       Abidjan  Côte D'Ivoire    5.63N     3.23W
# 2       Abidjan  Côte D'Ivoire    5.63N     3.23W
# 3       Abidjan  Côte D'Ivoire    5.63N     3.23W
# 4       Abidjan  Côte D'Ivoire    5.63N     3.23W
# ...         ...            ...      ...       ...
# 239172     Xian          China   34.56N   108.97E
# 239173     Xian          China   34.56N   108.97E
# 239174     Xian          China   34.56N   108.97E
# 239175     Xian          China   34.56N   108.97E
# 239176     Xian          China   34.56N   108.97E
#
# [239177 rows x 7 columns]>

# %%
df.drop(['City', 'Latitude', 'Longitude'], axis = 1, inplace = True)
display(df)
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
# 239176  2013-09-01                 NaN                            NaN
#
#               Country
# 0       Côte D'Ivoire
# 1       Côte D'Ivoire
# 2       Côte D'Ivoire
# 3       Côte D'Ivoire
# 4       Côte D'Ivoire
# ...               ...
# 239172          China
# 239173          China
# 239174          China
# 239175          China
# 239176          China
#
# [239177 rows x 4 columns]

# %%
df['dt'] = pd.to_datetime(df['dt'])
get_data = (df['dt'] > '1945-01-01') & (df['dt'] <= '2013-09-01')
df.loc[get_data]

df = df.loc[get_data]
display(df)
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty  \
# 1153   1945-02-01              27.933                          0.394
# 1154   1945-03-01              28.512                          0.354
# 1155   1945-04-01              27.967                          0.438
# 1156   1945-05-01              27.193                          0.301
# 1157   1945-06-01              25.786                          0.237
# ...           ...                 ...                            ...
# 239172 2013-05-01              18.979                          0.807
# 239173 2013-06-01              23.522                          0.647
# 239174 2013-07-01              25.251                          1.042
# 239175 2013-08-01              24.528                          0.840
# 239176 2013-09-01                 NaN                            NaN
#
#               Country
# 1153    Côte D'Ivoire
# 1154    Côte D'Ivoire
# 1155    Côte D'Ivoire
# 1156    Côte D'Ivoire
# 1157    Côte D'Ivoire
# ...               ...
# 239172          China
# 239173          China
# 239174          China
# 239175          China
# 239176          China
#
# [82400 rows x 4 columns]

# %%
df = df.loc[df['Country'].isin(['China'])]
display(df)
# Out:
#                dt  AverageTemperature  AverageTemperatureUncertainty Country
# 48532  1945-02-01             -15.565                          0.575   China
# 48533  1945-03-01              -4.664                          0.356   China
# 48534  1945-04-01               8.177                          0.562   China
# 48535  1945-05-01              12.963                          0.447   China
# 48536  1945-06-01              19.603                          0.561   China
# ...           ...                 ...                            ...     ...
# 239172 2013-05-01              18.979                          0.807   China
# 239173 2013-06-01              23.522                          0.647   China
# 239174 2013-07-01              25.251                          1.042   China
# 239175 2013-08-01              24.528                          0.840   China
# 239176 2013-09-01                 NaN                            NaN   China
#
# [13184 rows x 4 columns]

# %%
df.drop(['Country'], axis = 1, inplace = True)
df.reset_index(drop = True)
# Out:
#               dt  AverageTemperature  AverageTemperatureUncertainty
# 0     1945-02-01             -15.565                          0.575
# 1     1945-03-01              -4.664                          0.356
# 2     1945-04-01               8.177                          0.562
# 3     1945-05-01              12.963                          0.447
# 4     1945-06-01              19.603                          0.561
# ...          ...                 ...                            ...
# 13179 2013-05-01              18.979                          0.807
# 13180 2013-06-01              23.522                          0.647
# 13181 2013-07-01              25.251                          1.042
# 13182 2013-08-01              24.528                          0.840
# 13183 2013-09-01                 NaN                            NaN
#
# [13184 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# dt                                0
# AverageTemperature               16
# AverageTemperatureUncertainty    16
# dtype: int64

# %%
df.dropna(subset = ['AverageTemperature'], inplace = True)
df.dropna(subset = ['AverageTemperatureUncertainty'], inplace = True)
df.isnull().sum()
# Out:
# dt                               0
# AverageTemperature               0
# AverageTemperatureUncertainty    0
# dtype: int64

# %%
df_plot = df
df_plot[df_plot.columns.to_list()].plot(subplots = True, figsize = (20, 10))
plt.show()

# %%
dates = df['dt'].values
temp = df['AverageTemperature'].values

dates = np.array(dates)
temp = np.array(temp)

plt.figure(figsize = (20, 10))
plt.plot(dates, temp)

plt.title('Average Temperature', fontsize = 15)
plt.ylabel('Temperature')
plt.xlabel('Datetime')
# Out:
# Text(0.5, 0, 'Datetime')

# %%
df.dtypes
# Out:
# dt                               datetime64[ns]
# AverageTemperature                      float64
# AverageTemperatureUncertainty           float64
# dtype: object

# %%
# split dataset
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(temp, dates, train_size = 0.8, test_size = 0.2, shuffle = False)

print('Jumlah Data Train : ', len(x_train))
print('Jumlah Data Validation : ', len(x_valid))

def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
  series = tf.expand_dims(series, axis = -1)
  ds = tf.data.Dataset.from_tensor_slices(series)
  ds = ds.window(window_size + 1, shift = 1, drop_remainder = True)
  ds = ds.flat_map(lambda w : w.batch(window_size + 1))
  ds = ds.shuffle(shuffle_buffer)
  ds = ds.map(lambda w : (w[:-1], w[-1:]))
  return ds.batch(batch_size).prefetch(1)
# Out:
# Jumlah Data Train :  10534
# Jumlah Data Validation :  2634

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense,Bidirectional,Dropout

tf.keras.backend.set_floatx('float64')

train_set = windowed_dataset(x_train, window_size = 64, batch_size = 200, shuffle_buffer = 1000)
val_set = windowed_dataset(x_valid, window_size = 64, batch_size = 200, shuffle_buffer = 1000)

model = Sequential([
    Bidirectional(LSTM(60, return_sequences=True)),
    Bidirectional(LSTM(60)),
    Dense(30, activation="relu"),
    Dense(10, activation="relu"),
    Dense(1),
])

# %%
Mae = (df['AverageTemperature'].max() - df['AverageTemperature'].min()) * 10/100
print(Mae)
# Out:
# 5.5093000000000005

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('mae') < 5.5 and logs.get('val_mae') < 5.5):
      print("Mae < 10% data")
      self.model.stop_training = True
callbacks = myCallback()

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=1.0000e-04, momentum=0.9)

model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

history = model.fit(train_set, epochs=100, validation_data = val_set, callbacks=[callbacks])
# Out:
# Epoch 1/100
# 53/53 [==============================] - 13s 165ms/step - loss: 13.9109 - mae: 14.4049 - val_loss: 13.8717 - val_mae: 14.3637
# Epoch 2/100
# 53/53 [==============================] - 8s 145ms/step - loss: 13.7961 - mae: 14.2901 - val_loss: 13.7997 - val_mae: 14.2915
# Epoch 3/100
# 53/53 [==============================] - 8s 152ms/step - loss: 13.7331 - mae: 14.2270 - val_loss: 13.7327 - val_mae: 14.2247
# Epoch 4/100
# 53/53 [==============================] - 8s 148ms/step - loss: 13.6736 - mae: 14.1673 - val_loss: 13.6662 - val_mae: 14.1585
# Epoch 5/100
# 53/53 [==============================] - 8s 147ms/step - loss: 13.6120 - mae: 14.1056 - val_loss: 13.5939 - val_mae: 14.0866
# Epoch 6/100
# 53/53 [==============================] - 8s 145ms/step - loss: 13.5429 - mae: 14.0364 - val_loss: 13.5110 - val_mae: 14.0043
# Epoch 7/100
# 53/53 [==============================] - 8s 146ms/step - loss: 13.4628 - mae: 13.9565 - val_loss: 13.4133 - val_mae: 13.9070
# Epoch 8/100
# 53/53 [==============================] - 8s 144ms/step - loss: 13.3645 - mae: 13.8582 - val_loss: 13.2853 - val_mae: 13.7791
# Epoch 9/100
# 53/53 [==============================] - 8s 148ms/step - loss: 13.2313 - mae: 13.7250 - val_loss: 13.1111 - val_mae: 13.6048
# Epoch 10/100
# 53/53 [==============================] - 8s 152ms/step - loss: 13.0563 - mae: 13.5498 - val_loss: 12.8827 - val_mae: 13.3771
# Epoch 11/100
# 53/53 [==============================] - 8s 147ms/step - loss: 12.8239 - mae: 13.3171 - val_loss: 12.5732 - val_mae: 13.0683
# Epoch 12/100
# 53/53 [==============================] - 8s 153ms/step - loss: 12.5070 - mae: 13.0008 - val_loss: 12.1413 - val_mae: 12.6360
# Epoch 13/100
# 53/53 [==============================] - 8s 153ms/step - loss: 12.0676 - mae: 12.5599 - val_loss: 11.5386 - val_mae: 12.0309
# Epoch 14/100
# 53/53 [==============================] - 8s 155ms/step - loss: 11.4554 - mae: 11.9481 - val_loss: 10.7209 - val_mae: 11.2083
# Epoch 15/100
# 53/53 [==============================] - 8s 155ms/step - loss: 10.6390 - mae: 11.1309 - val_loss: 9.7644 - val_mae: 10.2536
# Epoch 16/100
# 53/53 [==============================] - 8s 155ms/step - loss: 9.7244 - mae: 10.2152 - val_loss: 8.8662 - val_mae: 9.3602
# Epoch 17/100
# 53/53 [==============================] - 8s 151ms/step - loss: 8.9218 - mae: 9.4159 - val_loss: 8.1826 - val_mae: 8.6729
# Epoch 18/100
# 53/53 [==============================] - 8s 151ms/step - loss: 8.3840 - mae: 8.8759 - val_loss: 7.9118 - val_mae: 8.4059
# Epoch 19/100
# 53/53 [==============================] - 8s 150ms/step - loss: 8.1428 - mae: 8.6332 - val_loss: 7.8160 - val_mae: 8.3094
# Epoch 20/100
# 53/53 [==============================] - 8s 151ms/step - loss: 8.0448 - mae: 8.5333 - val_loss: 7.7529 - val_mae: 8.2435
# Epoch 21/100
# 53/53 [==============================] - 8s 151ms/step - loss: 7.9652 - mae: 8.4538 - val_loss: 7.6845 - val_mae: 8.1740
# Epoch 22/100
# 53/53 [==============================] - 8s 151ms/step - loss: 7.8787 - mae: 8.3674 - val_loss: 7.6045 - val_mae: 8.0935
# Epoch 23/100
# 53/53 [==============================] - 8s 151ms/step - loss: 7.7800 - mae: 8.2688 - val_loss: 7.5148 - val_mae: 8.0032
# Epoch 24/100
# 53/53 [==============================] - 8s 151ms/step - loss: 7.6755 - mae: 8.1646 - val_loss: 7.4171 - val_mae: 7.9049
# Epoch 25/100
# 53/53 [==============================] - 8s 151ms/step - loss: 7.5629 - mae: 8.0522 - val_loss: 7.3098 - val_mae: 7.7965
# Epoch 26/100
# 53/53 [==============================] - 8s 151ms/step - loss: 7.4381 - mae: 7.9277 - val_loss: 7.1854 - val_mae: 7.6721
# Epoch 27/100
# 53/53 [==============================] - 8s 151ms/step - loss: 7.2927 - mae: 7.7827 - val_loss: 7.0401 - val_mae: 7.5269
# Epoch 28/100
# 53/53 [==============================] - 8s 151ms/step - loss: 7.1317 - mae: 7.6216 - val_loss: 6.8792 - val_mae: 7.3656
# Epoch 29/100
# 53/53 [==============================] - 8s 150ms/step - loss: 6.9495 - mae: 7.4399 - val_loss: 6.6608 - val_mae: 7.1473
# Epoch 30/100
# 53/53 [==============================] - 8s 151ms/step - loss: 6.7070 - mae: 7.1967 - val_loss: 6.3986 - val_mae: 6.8847
# Epoch 31/100
# 53/53 [==============================] - 8s 151ms/step - loss: 6.4230 - mae: 6.9125 - val_loss: 6.0668 - val_mae: 6.5518
# Epoch 32/100
# 53/53 [==============================] - 8s 151ms/step - loss: 6.0580 - mae: 6.5463 - val_loss: 5.6262 - val_mae: 6.1093
# Epoch 33/100
# 53/53 [==============================] - 8s 151ms/step - loss: 5.5796 - mae: 6.0651 - val_loss: 5.0562 - val_mae: 5.5386
# Epoch 34/100
# 53/53 [==============================] - ETA: 0s - loss: 4.9455 - mae: 5.4272Mae < 10% data
# 53/53 [==============================] - 8s 151ms/step - loss: 4.9455 - mae: 5.4272 - val_loss: 4.2790 - val_mae: 4.7604

# %%
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('Model Accuracy')
plt.xlabel('epoch')
plt.ylabel('Mae')
plt.legend(['Train', 'Val'], loc = 'best')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Train', 'Val'], loc = 'best')
plt.show()
